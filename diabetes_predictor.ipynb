# %% [markdown]
# ### Linear Regression on Diabetes Data / Diabetes Prediction

# %%
#pip install scikit-learn

# %%
import pandas as pd

# %%
from sklearn.datasets import load_diabetes

# Load the dataset
diabetes = load_diabetes()

df = pd.DataFrame(data=diabetes.data, columns=diabetes.feature_names)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 442 entries, 0 to 441
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   age     442 non-null    float64
#  1   sex     442 non-null    float64
#  2   bmi     442 non-null    float64
#  3   bp      442 non-null    float64
#  4   s1      442 non-null    float64
#  5   s2      442 non-null    float64
#  6   s3      442 non-null    float64
#  7   s4      442 non-null    float64
#  8   s5      442 non-null    float64
#  9   s6      442 non-null    float64
# dtypes: float64(10)
# memory usage: 34.7 KB

# %%
df.describe()
# Out:
#                 age           sex           bmi            bp            s1  \
# count  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02
# mean  -2.511817e-19  1.230790e-17 -2.245564e-16 -4.797570e-17 -1.381499e-17
# std    4.761905e-02  4.761905e-02  4.761905e-02  4.761905e-02  4.761905e-02
# min   -1.072256e-01 -4.464164e-02 -9.027530e-02 -1.123988e-01 -1.267807e-01
# 25%   -3.729927e-02 -4.464164e-02 -3.422907e-02 -3.665608e-02 -3.424784e-02
# 50%    5.383060e-03 -4.464164e-02 -7.283766e-03 -5.670422e-03 -4.320866e-03
# 75%    3.807591e-02  5.068012e-02  3.124802e-02  3.564379e-02  2.835801e-02
# max    1.107267e-01  5.068012e-02  1.705552e-01  1.320436e-01  1.539137e-01
#
#                  s2            s3            s4            s5            s6
# count  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02
# mean   3.918434e-17 -5.777179e-18 -9.042540e-18  9.293722e-17  1.130318e-17
# std    4.761905e-02  4.761905e-02  4.761905e-02  4.761905e-02  4.761905e-02
# min   -1.156131e-01 -1.023071e-01 -7.639450e-02 -1.260971e-01 -1.377672e-01
# 25%   -3.035840e-02 -3.511716e-02 -3.949338e-02 -3.324559e-02 -3.317903e-02
# 50%   -3.819065e-03 -6.584468e-03 -2.592262e-03 -1.947171e-03 -1.077698e-03
# 75%    2.984439e-02  2.931150e-02  3.430886e-02  3.243232e-02  2.791705e-02
# max    1.987880e-01  1.811791e-01  1.852344e-01  1.335973e-01  1.356118e-01

# %%
df.corr()
# Out:
#           age       sex       bmi        bp        s1        s2        s3  \
# age  1.000000  0.173737  0.185085  0.335428  0.260061  0.219243 -0.075181
# sex  0.173737  1.000000  0.088161  0.241010  0.035277  0.142637 -0.379090
# bmi  0.185085  0.088161  1.000000  0.395411  0.249777  0.261170 -0.366811
# bp   0.335428  0.241010  0.395411  1.000000  0.242464  0.185548 -0.178762
# s1   0.260061  0.035277  0.249777  0.242464  1.000000  0.896663  0.051519
# s2   0.219243  0.142637  0.261170  0.185548  0.896663  1.000000 -0.196455
# s3  -0.075181 -0.379090 -0.366811 -0.178762  0.051519 -0.196455  1.000000
# s4   0.203841  0.332115  0.413807  0.257650  0.542207  0.659817 -0.738493
# s5   0.270774  0.149916  0.446157  0.393480  0.515503  0.318357 -0.398577
# s6   0.301731  0.208133  0.388680  0.390430  0.325717  0.290600 -0.273697
#
#            s4        s5        s6
# age  0.203841  0.270774  0.301731
# sex  0.332115  0.149916  0.208133
# bmi  0.413807  0.446157  0.388680
# bp   0.257650  0.393480  0.390430
# s1   0.542207  0.515503  0.325717
# s2   0.659817  0.318357  0.290600
# s3  -0.738493 -0.398577 -0.273697
# s4   1.000000  0.617859  0.417212
# s5   0.617859  1.000000  0.464669
# s6   0.417212  0.464669  1.000000

# %%
X=df.drop(columns='s6')
y=df['s6']
X, y
# Out:
# (          age       sex       bmi        bp        s1        s2        s3  \
#  0    0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
#  1   -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
#  2    0.085299  0.050680  0.044451 -0.005670 -0.045599 -0.034194 -0.032356
#  3   -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
#  4    0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
#  ..        ...       ...       ...       ...       ...       ...       ...
#  437  0.041708  0.050680  0.019662  0.059744 -0.005697 -0.002566 -0.028674
#  438 -0.005515  0.050680 -0.015906 -0.067642  0.049341  0.079165 -0.028674
#  439  0.041708  0.050680 -0.015906  0.017293 -0.037344 -0.013840 -0.024993
#  440 -0.045472 -0.044642  0.039062  0.001215  0.016318  0.015283 -0.028674
#  441 -0.045472 -0.044642 -0.073030 -0.081413  0.083740  0.027809  0.173816
#
#             s4        s5
#  0   -0.002592  0.019907
#  1   -0.039493 -0.068332
#  2   -0.002592  0.002861
#  3    0.034309  0.022688
#  4   -0.002592 -0.031988
#  ..        ...       ...
#  437 -0.002592  0.031193
#  438  0.034309 -0.018114
#  439 -0.011080 -0.046883
#  440  0.026560  0.044529
#  441 -0.039493 -0.004222
#
#  [442 rows x 9 columns],
#  0     -0.017646
#  1     -0.092204
#  2     -0.025930
#  3     -0.009362
#  4     -0.046641
#           ...
#  437    0.007207
#  438    0.044485
#  439    0.015491
#  440   -0.025930
#  441    0.003064
#  Name: s6, Length: 442, dtype: float64)

# %%
from sklearn.linear_model import LinearRegression
linear_regression_model = LinearRegression()
linear_regression_model
# Out:
# LinearRegression()

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.2)
X_train
# Out:
#           age       sex       bmi        bp        s1        s2        s3  \
# 417 -0.052738 -0.044642  0.071397 -0.074527 -0.015328 -0.001314  0.004460
# 337  0.019913  0.050680 -0.012673  0.070072 -0.011201  0.007141 -0.039719
# 0    0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 293 -0.070900 -0.044642  0.092953  0.012680  0.020446  0.042527  0.000779
# 81   0.012648  0.050680 -0.022373 -0.029770  0.010815  0.028435 -0.021311
# ..        ...       ...       ...       ...       ...       ...       ...
# 377  0.019913  0.050680  0.009961  0.018430  0.014942  0.044719 -0.061809
# 169 -0.001882 -0.044642 -0.026684  0.049415  0.058973 -0.016032 -0.047082
# 379 -0.001882 -0.044642 -0.038540  0.021872 -0.108893 -0.115613  0.022869
# 187 -0.067268 -0.044642 -0.054707 -0.026328 -0.075870 -0.082106  0.048640
# 347  0.038076  0.050680 -0.029918 -0.074527 -0.012577 -0.012587  0.004460
#
#            s4        s5
# 417 -0.021412 -0.046883
# 337  0.034309  0.005386
# 0   -0.002592  0.019907
# 293  0.000360 -0.054540
# 81   0.034309 -0.006081
# ..        ...       ...
# 377  0.071210  0.009434
# 169  0.071210  0.133597
# 379 -0.076395 -0.046883
# 187 -0.076395 -0.086827
# 347 -0.002592  0.003709
#
# [353 rows x 9 columns]

# %%
from sklearn.linear_model import LinearRegression

linear_regression_model = LinearRegression()

linear_regression_model.fit(X_train, y_train)
linear_regression_model.coef_
# Out:
# array([ 0.10745821,  0.06256644,  0.11901539,  0.19141586, -0.16536476,
#         0.24720536,  0.03847544,  0.01987101,  0.25441777])

# %%
y_predicted = linear_regression_model.predict(X_test)
y_predicted
# Out:
# array([ 0.00608819,  0.03477493,  0.00202926, -0.02118952, -0.04587976,
#        -0.00239823, -0.00636072,  0.01995194,  0.02346378, -0.0260365 ,
#         0.00698793,  0.00459578,  0.01046596,  0.01295002, -0.01396404,
#        -0.03301901,  0.01305734, -0.01546722,  0.04969528, -0.02318918,
#        -0.01550873,  0.01827513,  0.01317793,  0.00711871, -0.0295811 ,
#        -0.00282849,  0.00207451,  0.03244147,  0.02140796,  0.02663128,
#        -0.0301885 ,  0.01465069,  0.02569934, -0.00274341, -0.02811878,
#        -0.01700371,  0.04550378,  0.04681582,  0.01840923,  0.00143976,
#        -0.02319469,  0.03849836, -0.02594979, -0.01549056, -0.00995947,
#        -0.02770513,  0.00131478, -0.01334794,  0.03811271,  0.02036559,
#         0.0022289 ,  0.02497558,  0.01999297, -0.02359395, -0.04516266,
#        -0.00336024, -0.00807909,  0.00487882,  0.03206676, -0.05126951,
#         0.0093087 , -0.04717511,  0.00897368, -0.03422492,  0.04034718,
#         0.01695938,  0.02359171, -0.03266133,  0.01875057,  0.04350506,
#         0.01774401, -0.03066066, -0.04763087, -0.04151931,  0.03930754,
#        -0.04861252,  0.00896489, -0.02594139,  0.02075673, -0.00529431,
#        -0.00562176, -0.05281486,  0.01247866,  0.0258467 , -0.02721201,
#         0.02012268, -0.01915041, -0.02465575, -0.02940421])

# %%
X_test
# Out:
#           age       sex       bmi        bp        s1        s2        s3  \
# 227  0.067136  0.050680 -0.029918  0.057437 -0.000193 -0.015719  0.074412
# 182  0.045341  0.050680  0.005650  0.056301  0.064477  0.089186 -0.039719
# 258  0.078034  0.050680 -0.024529 -0.042406  0.006687  0.052861 -0.069172
# 435 -0.012780 -0.044642 -0.023451 -0.040099 -0.016704  0.004636 -0.017629
# 84   0.001751 -0.044642 -0.039618 -0.100934 -0.029088 -0.030124  0.044958
# ..        ...       ...       ...       ...       ...       ...       ...
# 22  -0.085430 -0.044642 -0.004050 -0.009113 -0.002945  0.007767  0.022869
# 423  0.009016  0.050680 -0.039618  0.028758  0.038334  0.073529 -0.072854
# 134 -0.074533 -0.044642  0.043373 -0.033213  0.012191  0.000252  0.063367
# 312 -0.074533 -0.044642 -0.023451 -0.005670 -0.020832 -0.014153  0.015505
# 158 -0.012780 -0.044642 -0.065486 -0.069948  0.001183  0.016849 -0.002903
#
#            s4        s5
# 227 -0.050564 -0.038460
# 182  0.071210  0.015568
# 258  0.080804 -0.037129
# 435 -0.002592 -0.038460
# 84  -0.050195 -0.068332
# ..        ...       ...
# 22  -0.039493 -0.061176
# 423  0.108111  0.015568
# 134 -0.039493 -0.027129
# 312 -0.039493 -0.038460
# 158 -0.007020 -0.030748
#
# [89 rows x 9 columns]

# %%
# record_64 =X_test.loc[[64]]
# y_64_predicted = linear_regression_model.predict(record_64)
# y_64_predicted, y_test.loc[[64]]

# %%
results = pd.DataFrame({
     "y_actual": y_test,
     "y_predicted": y_predicted
 })

results
# Out:
#      y_actual  y_predicted
# 227  0.007207     0.006088
# 182 -0.009362     0.034775
# 258  0.056912     0.002029
# 435 -0.038357    -0.021190
# 84  -0.129483    -0.045880
# ..        ...          ...
# 22  -0.013504    -0.027212
# 423 -0.046641     0.020123
# 134 -0.046641    -0.019150
# 312 -0.030072    -0.024656
# 158 -0.050783    -0.029404
#
# [89 rows x 2 columns]

# %%
from sklearn.metrics import mean_absolute_error, root_mean_squared_error
mae = mean_absolute_error(y_predicted, y_test)
rmse = root_mean_squared_error(y_predicted, y_test)
mae, rmse
# Out:
# (0.031597525477373496, 0.04072352040086422)

# %%
from sklearn.metrics import mean_absolute_error, root_mean_squared_error, mean_squared_error,r2_score
mae = mean_absolute_error(y_predicted, y_test)
mse = mean_squared_error(y_predicted, y_test)
rmse = root_mean_squared_error(y_predicted, y_test)
mae,mse, rmse
# Out:
# (0.031597525477373496, 0.0016584051138396048, 0.04072352040086422)
