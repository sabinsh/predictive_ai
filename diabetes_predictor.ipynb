# %% [markdown]
# ### Linear Regression on Diabetes Data / Diabetes Prediction

# %%
pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in c:\users\sabin\appdata\local\programs\python\python313\lib\site-packages (1.7.1)
# Requirement already satisfied: numpy>=1.22.0 in c:\users\sabin\appdata\local\programs\python\python313\lib\site-packages (from scikit-learn) (2.3.2)
# Requirement already satisfied: scipy>=1.8.0 in c:\users\sabin\appdata\local\programs\python\python313\lib\site-packages (from scikit-learn) (1.16.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\sabin\appdata\local\programs\python\python313\lib\site-packages (from scikit-learn) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\sabin\appdata\local\programs\python\python313\lib\site-packages (from scikit-learn) (3.6.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
from sklearn.datasets import load_diabetes

# Load the dataset
diabetes = load_diabetes()

df = pd.DataFrame(data=diabetes.data, columns=diabetes.feature_names)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 442 entries, 0 to 441
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   age     442 non-null    float64
#  1   sex     442 non-null    float64
#  2   bmi     442 non-null    float64
#  3   bp      442 non-null    float64
#  4   s1      442 non-null    float64
#  5   s2      442 non-null    float64
#  6   s3      442 non-null    float64
#  7   s4      442 non-null    float64
#  8   s5      442 non-null    float64
#  9   s6      442 non-null    float64
# dtypes: float64(10)
# memory usage: 34.7 KB

# %%
df.describe()
# Out:
#                 age           sex           bmi            bp            s1  \
# count  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02
# mean  -2.511817e-19  1.230790e-17 -2.245564e-16 -4.797570e-17 -1.381499e-17
# std    4.761905e-02  4.761905e-02  4.761905e-02  4.761905e-02  4.761905e-02
# min   -1.072256e-01 -4.464164e-02 -9.027530e-02 -1.123988e-01 -1.267807e-01
# 25%   -3.729927e-02 -4.464164e-02 -3.422907e-02 -3.665608e-02 -3.424784e-02
# 50%    5.383060e-03 -4.464164e-02 -7.283766e-03 -5.670422e-03 -4.320866e-03
# 75%    3.807591e-02  5.068012e-02  3.124802e-02  3.564379e-02  2.835801e-02
# max    1.107267e-01  5.068012e-02  1.705552e-01  1.320436e-01  1.539137e-01
#
#                  s2            s3            s4            s5            s6
# count  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02
# mean   3.918434e-17 -5.777179e-18 -9.042540e-18  9.293722e-17  1.130318e-17
# std    4.761905e-02  4.761905e-02  4.761905e-02  4.761905e-02  4.761905e-02
# min   -1.156131e-01 -1.023071e-01 -7.639450e-02 -1.260971e-01 -1.377672e-01
# 25%   -3.035840e-02 -3.511716e-02 -3.949338e-02 -3.324559e-02 -3.317903e-02
# 50%   -3.819065e-03 -6.584468e-03 -2.592262e-03 -1.947171e-03 -1.077698e-03
# 75%    2.984439e-02  2.931150e-02  3.430886e-02  3.243232e-02  2.791705e-02
# max    1.987880e-01  1.811791e-01  1.852344e-01  1.335973e-01  1.356118e-01

# %%
df.corr()
# Out:
#           age       sex       bmi        bp        s1        s2        s3  \
# age  1.000000  0.173737  0.185085  0.335428  0.260061  0.219243 -0.075181
# sex  0.173737  1.000000  0.088161  0.241010  0.035277  0.142637 -0.379090
# bmi  0.185085  0.088161  1.000000  0.395411  0.249777  0.261170 -0.366811
# bp   0.335428  0.241010  0.395411  1.000000  0.242464  0.185548 -0.178762
# s1   0.260061  0.035277  0.249777  0.242464  1.000000  0.896663  0.051519
# s2   0.219243  0.142637  0.261170  0.185548  0.896663  1.000000 -0.196455
# s3  -0.075181 -0.379090 -0.366811 -0.178762  0.051519 -0.196455  1.000000
# s4   0.203841  0.332115  0.413807  0.257650  0.542207  0.659817 -0.738493
# s5   0.270774  0.149916  0.446157  0.393480  0.515503  0.318357 -0.398577
# s6   0.301731  0.208133  0.388680  0.390430  0.325717  0.290600 -0.273697
#
#            s4        s5        s6
# age  0.203841  0.270774  0.301731
# sex  0.332115  0.149916  0.208133
# bmi  0.413807  0.446157  0.388680
# bp   0.257650  0.393480  0.390430
# s1   0.542207  0.515503  0.325717
# s2   0.659817  0.318357  0.290600
# s3  -0.738493 -0.398577 -0.273697
# s4   1.000000  0.617859  0.417212
# s5   0.617859  1.000000  0.464669
# s6   0.417212  0.464669  1.000000

# %%
X=df.drop(columns='s6')
y=df['s6']
X, y
# Out:
# (          age       sex       bmi        bp        s1        s2        s3  \
#  0    0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
#  1   -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
#  2    0.085299  0.050680  0.044451 -0.005670 -0.045599 -0.034194 -0.032356
#  3   -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
#  4    0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
#  ..        ...       ...       ...       ...       ...       ...       ...
#  437  0.041708  0.050680  0.019662  0.059744 -0.005697 -0.002566 -0.028674
#  438 -0.005515  0.050680 -0.015906 -0.067642  0.049341  0.079165 -0.028674
#  439  0.041708  0.050680 -0.015906  0.017293 -0.037344 -0.013840 -0.024993
#  440 -0.045472 -0.044642  0.039062  0.001215  0.016318  0.015283 -0.028674
#  441 -0.045472 -0.044642 -0.073030 -0.081413  0.083740  0.027809  0.173816
#
#             s4        s5
#  0   -0.002592  0.019907
#  1   -0.039493 -0.068332
#  2   -0.002592  0.002861
#  3    0.034309  0.022688
#  4   -0.002592 -0.031988
#  ..        ...       ...
#  437 -0.002592  0.031193
#  438  0.034309 -0.018114
#  439 -0.011080 -0.046883
#  440  0.026560  0.044529
#  441 -0.039493 -0.004222
#
#  [442 rows x 9 columns],
#  0     -0.017646
#  1     -0.092204
#  2     -0.025930
#  3     -0.009362
#  4     -0.046641
#           ...
#  437    0.007207
#  438    0.044485
#  439    0.015491
#  440   -0.025930
#  441    0.003064
#  Name: s6, Length: 442, dtype: float64)

# %%
from sklearn.linear_model import LinearRegression
linear_regression_model = LinearRegression()
linear_regression_model
# Out:
# LinearRegression()

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.2)
X_train
# Out:
#           age       sex       bmi        bp        s1        s2        s3  \
# 127  0.034443  0.050680 -0.001895 -0.012556  0.038334  0.013717  0.078093
# 170  0.023546  0.050680 -0.020218 -0.036656 -0.013953 -0.015092  0.059685
# 349  0.001751  0.050680 -0.057941 -0.043542 -0.096510 -0.047034 -0.098625
# 386  0.019913 -0.044642 -0.040696 -0.015999 -0.008449 -0.017598  0.052322
# 61  -0.041840  0.050680  0.004572 -0.053870 -0.044223 -0.027305 -0.080217
# ..        ...       ...       ...       ...       ...       ...       ...
# 138  0.034443  0.050680  0.111276  0.076958 -0.031840 -0.033881 -0.021311
# 193  0.009016  0.050680 -0.005128 -0.064199  0.069981  0.083863 -0.039719
# 198 -0.052738 -0.044642  0.054152 -0.026328 -0.055231 -0.033881 -0.013948
# 216  0.012648  0.050680  0.035829  0.049415  0.053469  0.074155 -0.069172
# 143 -0.030942 -0.044642  0.005650 -0.009113  0.019070  0.006828  0.074412
#
#            s4        s5
# 127 -0.039493  0.004548
# 170 -0.039493 -0.096435
# 349  0.034309 -0.061176
# 386 -0.039493 -0.030748
# 61   0.071210  0.036644
# ..        ...       ...
# 138 -0.002592  0.028020
# 193  0.071210  0.039542
# 198 -0.039493 -0.074093
# 216  0.145012  0.045604
# 143 -0.039493 -0.041176
#
# [353 rows x 9 columns]

# %%
from sklearn.linear_model import LinearRegression

linear_regression_model = LinearRegression()

linear_regression_model.fit(X_train, y_train)
linear_regression_model.coef_
# Out:
# array([0.09673783, 0.06969436, 0.14777356, 0.12509988, 0.02615   ,
#        0.00592171, 0.0578916 , 0.1630717 , 0.23971398])

# %%
y_predicted = linear_regression_model.predict(X_test)
y_predicted
# Out:
# array([-3.73904231e-02,  3.09344626e-02,  8.43117794e-03, -3.02454295e-02,
#        -3.89690990e-03, -4.77761358e-02, -3.55202971e-02, -3.42140337e-02,
#        -1.70859987e-02,  2.15290007e-02, -2.63264500e-02,  5.70857695e-02,
#        -1.87518978e-02, -4.79663557e-03,  2.07859922e-02,  1.89832599e-02,
#         7.70096385e-03, -6.10326462e-03, -1.01229017e-02, -4.18749147e-02,
#         4.61218251e-02,  3.39063270e-04, -3.54976558e-02,  1.83760653e-02,
#         5.64225522e-03,  1.52808282e-02,  6.93804621e-03,  2.61361873e-02,
#        -1.64212940e-02, -5.00420956e-02,  1.34517543e-02, -2.33868563e-02,
#         2.08700723e-02,  1.72449778e-02, -5.54737321e-03,  3.61668469e-03,
#        -2.89923101e-02,  3.54430113e-02,  3.77260586e-02, -1.80038366e-02,
#         3.65157146e-02, -4.35967999e-02,  3.44461088e-02,  2.27276700e-02,
#         5.13733274e-02, -3.17659927e-02, -6.74263796e-03, -2.32206882e-02,
#         2.04965986e-02,  1.16252412e-02, -5.58317286e-03, -3.24392968e-02,
#         1.48968562e-02,  5.69851800e-03,  2.54644596e-02,  1.52070205e-02,
#         1.07086747e-02, -9.95779817e-04, -4.96592535e-03,  3.63343582e-02,
#         6.39885856e-03, -7.08680536e-04, -8.75176517e-03,  3.42792840e-02,
#        -8.08230085e-03, -4.15933709e-02,  5.69472997e-03, -1.09166664e-02,
#        -3.19368945e-02,  1.39259914e-02, -5.81911883e-05,  1.26793122e-02,
#        -1.62935605e-02,  4.20324173e-02, -1.03199839e-02,  4.75594817e-03,
#        -2.11381381e-02, -1.39190833e-02,  2.39048676e-02,  3.47830966e-02,
#        -1.50599292e-02, -3.93673883e-02,  2.32412062e-03,  1.44960871e-02,
#        -5.58507591e-05,  3.42898522e-02, -2.33948781e-02,  1.80832281e-02,
#        -3.57628221e-02])

# %%
X_test
# Out:
#           age       sex       bmi        bp        s1        s2        s3  \
# 64   0.067136  0.050680 -0.025607 -0.040099 -0.063487 -0.059873 -0.002903
# 235  0.067136  0.050680 -0.014828  0.058608 -0.059359 -0.034508 -0.061809
# 345  0.081666  0.050680 -0.002973 -0.033213  0.042462  0.057871 -0.010266
# 46  -0.056370 -0.044642 -0.011595 -0.033213 -0.046975 -0.047660  0.004460
# 90   0.012648 -0.044642 -0.025607 -0.040099 -0.030464 -0.045155  0.078093
# ..        ...       ...       ...       ...       ...       ...       ...
# 410 -0.009147  0.050680 -0.027762  0.008101  0.047965  0.037203 -0.028674
# 45   0.027178  0.050680 -0.035307  0.032201 -0.011201  0.001504 -0.010266
# 10  -0.096328 -0.044642 -0.083808  0.008101 -0.103389 -0.090561 -0.013948
# 240  0.048974  0.050680  0.074630  0.066629 -0.009825 -0.002253 -0.043401
# 182  0.045341  0.050680  0.005650  0.056301  0.064477  0.089186 -0.039719
#
#            s4        s5
# 64  -0.039493 -0.019198
# 235  0.012906 -0.005142
# 345  0.034309 -0.000612
# 46  -0.039493 -0.007977
# 90  -0.076395 -0.072133
# ..        ...       ...
# 410  0.034309  0.066051
# 45  -0.002592 -0.014960
# 10  -0.076395 -0.062917
# 240  0.034309  0.033654
# 182  0.071210  0.015568
#
# [89 rows x 9 columns]

# %%
record_64 =X_test.loc[[64]]
y_64_predicted = linear_regression_model.predict(record_64)
y_64_predicted, y_test.loc[[64]]
# Out:
# (array([-0.01194528]),
#  64    0.011349
#  Name: s6, dtype: float64)

# %%
# results = pd.DataFrame({
#     "y_actual": y_test,
#     "y_predicted": y_predicted
# })

# results

# %%
from sklearn.metrics import mean_absolute_error, root_mean_squared_error
mae = mean_absolute_error(y_predicted, y_test)
rmse = root_mean_squared_error(y_predicted, y_test)
mae, rmse
# Out:
# (0.029013910538727938, 0.03636066943167128)
